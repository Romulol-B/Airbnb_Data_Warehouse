# %%
# %pip install gdown -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os
project_root = os.path.abspath('..')
print(f"root:{project_root}")
if project_root not in sys.path:
    sys.path.append(project_root)
# Out:
# root:c:\Users\romul\Repositories\Airbnb_Data_Warehouse

# %%
import gdown 
url_clima = 'https://drive.google.com/uc?export=download&id=1hQyOGsjPs3j4hGnztif19lN9KZHVKomO'
url_listings = 'https://drive.google.com/uc?export=download&id=1JJV705h0aJWhuJEEpwojKNCnkOszfdTb'
url_reviews = 'https://drive.google.com/uc?export=download&id=1J1F0deJU-yGEe1BaMZI5HfyR1FLmhYpD'
#url_calendar = 
folder_path = f'{project_root}/data/raw'

# %%
gdown.download(url_clima, folder_path, quiet=False)
gdown.download(url_listings, folder_path, quiet=False)
gdown.download(url_reviews, folder_path, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1hQyOGsjPs3j4hGnztif19lN9KZHVKomO
# From (redirected): https://drive.google.com/uc?export=download&id=1hQyOGsjPs3j4hGnztif19lN9KZHVKomO&confirm=t&uuid=9fb12790-a867-4a6f-b5e5-a4884fdf6387
# To: c:\Users\romul\Repositories\Airbnb_Data_Warehouse\data\raw
# 100%|██████████| 849M/849M [00:22<00:00, 38.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1JJV705h0aJWhuJEEpwojKNCnkOszfdTb
# To: c:\Users\romul\Repositories\Airbnb_Data_Warehouse\data\raw
# 100%|██████████| 84.6M/84.6M [00:02<00:00, 34.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1J1F0deJU-yGEe1BaMZI5HfyR1FLmhYpD
# From (redirected): https://drive.google.com/uc?export=download&id=1J1F0deJU-yGEe1BaMZI5HfyR1FLmhYpD&confirm=t&uuid=9279661b-b422-45ab-aefb-6985cad00b36
# To: c:\Users\romul\Repositories\Airbnb_Data_Warehouse\data\raw
# ...
